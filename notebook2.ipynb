# %%
from manim import *
config.media_embed = True
config.media_width = "50%"
config.verbosity = "WARNING"

# %%
# %%manim -v WARNING -qh --disable_caching Wave
# import numpy as np
# from random import *
#
#
# class Wave(Scene):
#     def construct(self):
#
#         maze_string = """
# #######################################################
# #  #################            ##                    #
# # ##################           ####                   #
# # #################            ####                   #
# #  ###############             #####               # ##
# #      #########               #####               ####
# #         ###                  ######            ######
# #          ###            ##   #####    ###       #####
# #          ####      ########   ####  #####        ## #
# #          #####   ##########   ###  ########       # #
# #         #####   ###########        ########         #
# #         ####   ###########        ##########        #
# #        ##      ###########        ##########        #
# #      ####     ############      #############       #
# #    ######     ############     #############        #
# # #########  ## ###########     #########    #        #
# # ############### #########     #######               #
# # ###############   ######      ######                #
# # ###############    #####       ####                 #
# #   #############      #                ##            #
# #     #  #######                       ########### ####
# #          ###         #              #################
# # ##                  ####            #################
# #####                ######          ##################
# ######                ######         ##################
# # ###      ###        #######  ###   ###############  #
# #         ####         ############   ####  #######   #
# #        #####          ############          ###     #
# #         ###            ##########                   #
# #######################################################
# """
#
#         maze = []  # 2D array of squares like we see it
#         maze_bool = []  # 2D array of true/false values
#         all_squares = VGroup()
#
#         for row in maze_string.strip().split("\n"):
#             maze.append([])
#             maze_bool.append([])
#             for char in row:
#                 maze[-1].append(
#                     Square(
#                         color=WHITE if char == " " else BLACK,
#                         fill_opacity=1
#                     ).scale(0.1)
#                 )
#                 maze_bool[-1].append(char == " ")
#                 all_squares.add(maze[-1][-1])
#
#         rows = len(maze)
#         cols = len(maze[0])
#
#         self.play(FadeIn(all_squares.arrange_in_grid(rows, cols, buff=0.05)))
#
#         x, y = 1, 1
#         distances = {(x, y): 0}
#         stack = [(x, y, 0)]
#
#         while stack:
#             x, y, d = stack.pop(0)
#             for dx, dy in [(1, 0), (-1, 0), (0, 1), (0, -1)]:
#                 if x + dx < 0 or x + dx >= cols or y + dy < 0 or y + dy >= rows:
#                     continue
#                 if maze_bool[y + dy][x + dx] and (x + dx, y + dy) not in distances:
#                     distances[(x + dx, y + dy)] = d + 1
#                     stack.append((x + dx, y + dy, d + 1))
#
#         max_distance = max(distances.values())
#         colors = ["#ef476f", "#ffd166", "#06d6a0", "#118ab2"]
#         all_colors = color_gradient(colors, max_distance + 1)
#
#         group = []
#         for c in range(max_distance + 1):
#             group.append(
#                 AnimationGroup(
#                     *[
#                         maze[y][x].animate.set_color(color=all_colors[c])
#                         for x, y in distances.keys()
#                         if distances[(x, y)] == c
#                     ]
#                 )
#             )
#
#         self.play(AnimationGroup(*group, lag_ratio=0.02))
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -v WARNING -qh --disable_caching LifeGame
# import numpy as np
# import tkinter as tk
#
#
# class LifeGame(Scene):
#     def construct(self):
#         square = Square(color=WHITE, fill_opacity=1).scale(0.1)
# Out:
# Manim Community v0.18.1

# %%
# %%manim -v WARNING -qh --disable_caching LifeGame
# import numpy as np
#
# class LifeGame(Scene):
#     def construct(self):
