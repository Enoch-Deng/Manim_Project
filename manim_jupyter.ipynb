# %%
from manim import *
config.media_embed = True
config.media_width = "50%"
config.verbosity = "WARNING"

# %%
# %%manim -v WARNING  --progress_bar None  -qh --disable_caching HelloManim
#
# class HelloManim(Scene):
#     def construct(self):
#         self.camera.background_color = "#ece6e2"
#         banner_large = ManimBanner(dark_theme=False).scale(0.7)
#         self.play(banner_large.create())
#         self.play(banner_large.expand())
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# The building blocks in Manim are the **Scene** class and **Mobject** class. The class Intro is a subclass of Scene, inheriting all the methods of Scene. Each of the scenes must implement the construct method, which contains information about how the scene looks like (creating shapes, moving them, changing, color and size, etc.).
#
# There are also a number of builtin constants used (LEFT, RIGHT, RED, BLUE). These are constants that Manim uses to make the code more readable. For a more comprehensive list, here are the [colors](https://docs.manim.community/en/stable/reference/manim.utils.color.manim_colors.html) and here are other [constants](https://docs.manim.community/en/stable/reference/manim.constants.html).

# %% [markdown]
# To render the scene, we use the manim command:
#
#  * In command line: manim -pql xxxx.py Intro
#
# The -p flag plays the animation once it is rendered. If you want to open the file browser at the location of the animation instead of playing it, you can use the -f flag. You can also omit these two flags.
#
# * In Jupyter notebook: %%manim -v WARNING  --progress_bar None  -qh --disable_caching Intro
#
# The flag -v sets the verbosity level to WARNING.
#
# The flag -qh tells manim to hide the progress bar.
#
# The flag --disable_caching tells manim to disable caching.
#
# For both of these commands, the -ql flag (for low quality, 480p15) can be replaced by the -qh flag, for high quality (1080p60). Can also add more flags, such as -s -ql or -s -qh. You can also add -qm, -qh, -qp and -qk for medium (1280x720 30FPS), high (1920x1080 60FPS), 2k (2560x1440 60FPS) and 4k quality (3840x2160 60FPS), respectively.

# %% [markdown]
# Here is an example of a simple scene that creates a red Square and then a blue Circle.

# %%
# %%manim -v WARNING  --progress_bar None  -qh --disable_caching Intro
#
# class Intro(Scene):
#     def construct(self):
#         # create square and circle objects (and move them)
#         square = Square(color=RED).shift(LEFT * 2 + UP * 1.5)
#         circle = Circle(color=BLUE).shift(RIGHT * 2+ UP * 1.5)
#
#         # animate writing them on screen
#         self.play(Create(square), Create(circle))
#
#         # fading them from the scene
#         self.play(FadeOut(square), FadeOut(circle), run_time=2)
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
# ### **Class: `Intro(Scene)`**
# This is a class definition inheriting from `Scene`, which is part of the Manim library. The `Scene` class provides the framework for creating and animating mathematical visuals.
#
# ---
#
# ### **Method: `construct(self)`**
# This is the main method where **animations** and **objects** are defined. It is automatically called by Manim when rendering the scene.
#
# #### **1. `Square(color=RED).shift(LEFT * 2)`**
# - **Purpose**: Creates a red square object and shifts it 2 units to the left.
# - **Methods Used**:
#   - `Square(color=RED)`: Creates a square shape with the specified color (red).
#   - `.shift(LEFT * 2)`: Moves the square 2 units to the left.
#
# #### **2. `Circle(color=BLUE).shift(RIGHT * 2)`**
# - **Purpose**: Creates a blue circle object and shifts it 2 units to the right.
# - **Methods Used**:
#   - `Circle(color=BLUE)`: Creates a circle shape with the specified color (blue).
#   - `.shift(RIGHT * 2)`: Moves the circle 2 units to the right.
#   - Since the direction constants are NumPy arrays, they can be added and multiplied by constants with ease – to move to the side and slightly up, we can simply do `obj.shift(LEFT + UP * 1.5)`
#
# ---
#
# ### **Animation: `self.play(Create(square), Create(circle))`**
# - **Purpose**: Animates the appearance of the square and circle on the screen.
# - **Key Functionality**:
#   - `Create()`: An animation that draws the shapes progressively, making them appear as if they are being created.
#   - `self.play(...)`: Triggers the animations specified as arguments.
#
# ---
#
# ### **Animation: `self.play(FadeOut(square), FadeOut(circle), run_time=2)`**
# - **Purpose**: Animates the disappearance of the square and circle from the scene over a span of 2 seconds.
# - **Key Functionality**:
#   - `FadeOut()`: An animation that fades the objects out of the scene.
#   - `run_time=2`: Specifies the duration of the fade-out animation (2 seconds).

# %%
# %%manim -v WARNING  --progress_bar None  -qh --disable_caching Animate
#
# class Animate(Scene):
#     def construct(self):
#         square = Square(color=RED).shift(LEFT * 2)
#         circle = Circle(color=BLUE).shift(RIGHT * 2)
#
#         self.play(Write(square), Write(circle))
#
#         # moving objects
#         self.play(
#             square.animate.shift(UP * 0.5),
#             circle.animate.shift(DOWN * 0.5)
#         )
#
#         # rotating and filling the square (opacity 80%)
#         # scaling and filling the circle (opacity 80%)
#         self.play(
#             square.animate.rotate(PI / 2).set_fill(RED, 0.8),
#             circle.animate.scale(2).set_fill(BLUE, 0.8),
#         )
#
#         # change color
#         self.play(
#             square.animate.set_color(GREEN),
#             circle.animate.set_color(ORANGE),
#         )
#
#         self.play(FadeOut(square), FadeOut(circle))
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `Animate(Scene)`**
# This class defines another animation sequence using the Manim library, similar to the previous example but with added animations and transformations.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `self.play(Write(square), Write(circle))`**
# - **Purpose**: Animates the drawing of the square and circle as if they are being written or drawn stroke-by-stroke.
# - **Method**:
#   - `Write()`: A type of animation where objects are "written" or "drawn" progressively.
#
# ---
#
# #### **2. `square.animate.shift(UP * 0.5)` and `circle.animate.shift(DOWN * 0.5)`**
# - **Purpose**: Animates the movement of the square and circle vertically:
#   - The square moves **up** by 0.5 units.
#   - The circle moves **down** by 0.5 units.
# - **Method**:
#   - `.animate.shift(...)`: Allows smooth movement of the object to a new position during the animation.
#
# ---
#
# #### **3. Combined Animations**
# - **Purpose**: Adds rotation, scaling, and filling effects:
#   - **Square**:
#     - Rotates 90° (π/2 radians).
#     - Sets its fill color to red with 80% opacity.
#   - **Circle**:
#     - Scales to twice its original size.
#     - Sets its fill color to blue with 80% opacity.
# - **Methods**:
#   - `.animate.rotate(angle)`: Rotates the object by the given angle in radians.
#   - `.set_fill(color, opacity)`: Changes the object's fill color and opacity.
#   - `.animate.scale(factor)`: Resizes the object by the given scale factor.
#
# ---
#
# #### **4. `square.animate.set_color(GREEN)` and `circle.animate.set_color(ORANGE)`**
# - **Purpose**: Animates a color change:
#   - The square turns green.
#   - The circle turns orange.
# - **Method**:
#   - `.animate.set_color(color)`: Smoothly transitions the object's color to the specified value.
#
# ---
#
# #### **5. `self.play(FadeOut(square), FadeOut(circle))`**
# This is already explained in the previous code analysis. It fades out both shapes from the scene.
#
# ---
#
# ### Summary
# This script builds on the previous example and introduces:
# 1. Stroke-by-stroke writing of shapes (`Write`).
# 2. Smooth movement, rotation, scaling, and color transitions using `.animate`.
# 3. Combined transformations like rotation, scaling, and filling with animations.

# %%
# %%manim -v WARNING  --progress_bar None -qh --disable_caching NextTo
#
# class NextTo(Scene):
#     def construct(self):
#         # Create circles and a rectangle
#         circles = [Circle(radius=0.5, color=WHITE) for _ in range(4)] # _ is a common placeholder variable name when the loop variable is not used inside the loop body.
#         rectangle = Rectangle(width=5, height=3)
#
#         # Write all objects on the screen
#         self.play(*[Write(obj) for obj in circles + [rectangle]]) # The * operator unpacks the list of Write animations into individual arguments.
#
#         # Move the circles to surround the rectangle
#         positions = [LEFT, UP, RIGHT, DOWN]
#         animations = [
#             circle.animate.next_to(rectangle, direction)
#             for circle, direction in zip(circles, positions)
#         ]
#         self.play(*animations)
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `NextTo(Scene)`**
# This class builds an animation where circles are arranged around a rectangle using a clean and structured approach.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `circles = [Circle(radius=0.5, color=WHITE) for _ in range(4)]`**
# - **Purpose**: Creates a list of four white circles with a radius of 0.5.
# - **Key Points**:
#   - The list comprehension structure is identical to the previous example.
#   - `_`: A placeholder variable, commonly used when the loop variable is not needed.
#
# ---
#
# #### **2. `self.play(*[Write(obj) for obj in circles + [rectangle]])`**
# - **Purpose**: Animates the creation of all circles and the rectangle on the screen.
# - **Key Points**:
#   - `circles + [rectangle]`: Concatenates the list of circles with a list containing the rectangle.
#   - `*[Write(obj) for obj in ...]`: Creates `Write` animations for all objects and unpacks them as arguments to `self.play`.
#
# ---
#
# #### **3. `positions = [LEFT, UP, RIGHT, DOWN]`**
# - **Purpose**: Defines the directions where each circle will be positioned relative to the rectangle.
# - **Key Points**:
#   - `LEFT`, `UP`, `RIGHT`, and `DOWN`: Predefined constants in Manim representing standard directions.
#
# ---
#
# #### **4. `animations = [...]`**
# - **Purpose**: Creates a list of animations where each circle moves to a specified position around the rectangle.
# - **Key Points**:
#   - `zip(circles, positions)`: Combines the list of circles with the list of directions, pairing each circle with its corresponding direction.
#   - `circle.animate.next_to(rectangle, direction)`: Moves each circle to the position relative to the rectangle.
#
# ---
#
# #### **5. `self.play(*animations)`**
# - **Purpose**: Executes all the animations in `animations` simultaneously.
# - **Key Points**:
#   - `*animations`: Unpacks the list of animations into individual arguments for `self.play`.
#
# ---
#
# ### Improvements Over the Previous Example
# 1. **Readability**: Uses a structured and modular approach with variables like `positions` and `animations`.
# 2. **Conciseness**: Combines the circle positioning logic into a single list comprehension with `zip`.
# 3. **Flexibility**: The `positions` list allows for easy modification of the placement logic.
#
# ---
#
# ### Summary
# This script demonstrates:
# 1. Efficient list comprehensions to create objects and animations.
# 2. The use of `zip` to pair elements from two lists.
# 3. A modular and readable approach for animating complex scenes.

# %%
# %%manim -v WARNING -qh --disable_caching MoveTo
#
# class MoveTo(Scene):
#     def construct(self):
#         # Create squares
#         squares = [Square() for _ in range(3)]
#
#         # Display squares
#         self.play(*[Write(square) for square in squares])
#
#         # Align squares next to one another
#         self.play(
#             squares[0].animate.next_to(squares[1], LEFT),
#             squares[2].animate.next_to(squares[1], RIGHT),
#         )
#
#         # Create numbers and scale them
#         numbers = [Tex(f"${i}$").scale(3) for i in range(3)]
#
#         # Move numbers to corresponding squares
#         for number, square in zip(numbers, squares):
#             number.move_to(square)
#
#         # Display numbers
#         self.play(*[Write(number) for number in numbers])
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `MoveTo(Scene)`**
# This class creates a scene where squares are aligned horizontally, and numbers are placed inside them.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `squares = [Square() for _ in range(3)]`**
# - **Purpose**: Creates a list of three square objects.
# - **Key Points**:
#   - `Square()`: Instantiates a square with default properties.
#   - List comprehension is used to efficiently create multiple squares.
#
# ---
#
# #### **2. `self.play(*[Write(square) for square in squares])`**
# - **Purpose**: Animates the creation of the squares.
# - **Key Points**:
#   - The unpacking syntax (`*`) is used to pass each `Write` animation as an argument to `self.play`.
#
# ---
#
# #### **3. `squares[0].animate.next_to(squares[1], LEFT)` and `squares[2].animate.next_to(squares[1], RIGHT)`**
# - **Purpose**: Positions the squares horizontally:
#   - `squares[0]`: Moves to the left of `squares[1]`.
#   - `squares[2]`: Moves to the right of `squares[1]`.
# - **Method**:
#   - `.animate.next_to(mobject, direction)`: Moves an object to a position relative to another object (`mobject`) in the specified `direction`.
#
# ---
#
# #### **4. `numbers = [Tex(f"${i}$").scale(3) for i in range(3)]`**
# - **Purpose**: Creates a list of three large numbers (0, 1, 2) rendered as LaTeX.
# - **Key Points**:
#   - `Tex(f"${i}$")`: Renders the number `i` as LaTeX math (e.g., `"$0$"`).
#   - `.scale(3)`: Scales the text objects to be 3 times their default size.
#
# ---
#
# #### **5. `number.move_to(square)`**
# - **Purpose**: Positions each number at the center of its corresponding square.
# - **Method**:
#   - `.move_to(mobject)`: Moves an object to the position of another object (`mobject`).
#
# ---
#
# #### **6. `self.play(*[Write(number) for number in numbers])`**
# - **Purpose**: Animates the appearance of all the numbers inside the squares.
# - **Key Points**:
#   - `Write()`: Animates the stroke-by-stroke drawing of the text.
#
# ---
#
# ### Summary
# This script demonstrates:
# 1. **Object Creation**:
#    - Use of list comprehensions for creating multiple objects like squares and numbers.
# 2. **Object Positioning**:
#    - The `.animate.next_to()` method for relative positioning.
#    - The `.move_to()` method for precise alignment.
# 3. **Text and Shape Integration**:
#    - Rendering LaTeX text objects (`Tex`) and aligning them with geometric objects.
# 4. **Readable Animation Sequencing**:
#    - Modular approach with loops and unpacking for clean animation logic.

# %%
# %%manim -v WARNING -qh --disable_caching AlignTo
#
#
# class AlignTo(Scene):
#     def construct(self):
#         # Create circles with varying radii
#         circles = [Circle(radius=1.5 - i / 3, color=WHITE) for i in range(3)]
#
#         # Display circles
#         self.play(*[Write(circle) for circle in circles])
#
#         # Align c1 to the left and c3 to the right of c2
#         self.play(
#             circles[0].animate.next_to(circles[1], LEFT),
#             circles[2].animate.next_to(circles[1], RIGHT),
#         )
#
#         # Align bottoms of c1 and c3 with c2
#         self.play(
#             circles[0].animate.align_to(circles[1], DOWN),
#             circles[2].animate.align_to(circles[1], DOWN),
#         )
#
#         # Define the reference point for top alignment
#         point = [0, 2.5, 0]
#
#         # Align tops of all circles with the line passing through the point
#         self.play(
#             *[circle.animate.align_to(point, UP) for circle in circles]
#         )
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `AlignTo(Scene)`**
# This class creates a scene where circles are arranged and aligned with each other or a reference point.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `circles = [Circle(radius=1.5 - i / 3, color=WHITE) for i in range(3)]`**
# - **Purpose**: Creates three circles with decreasing radii.
# - **Key Points**:
#   - `Circle(radius=...)`: Instantiates a circle with a specified radius.
#   - `1.5 - i / 3`: Dynamically calculates the radius for each circle, reducing by `1/3` for each subsequent circle (`i` from 0 to 2).
#
# ---
#
# #### **2. `self.play(*[Write(circle) for circle in circles])`**
# - **Purpose**: Animates the creation of all three circles.
# - **Key Points**:
#   - The unpacking operator (`*`) is used to pass individual `Write` animations for the circles to `self.play`.
#
# ---
#
# #### **3. `circles[0].animate.align_to(circles[1], DOWN)` and Similar Lines**
# - **Purpose**: Aligns the bottoms of the first and third circles (`c1` and `c3`) with the bottom of the second circle (`c2`).
# - **Method**:
#   - `.align_to(mobject, direction)`: Aligns the specified edge of the current object to the corresponding edge of another object (`mobject`) in the specified `direction` (e.g., `DOWN`).
#
# ---
#
# #### **4. `point = [0, 2.5, 0]`**
# - **Purpose**: Defines a 3D point as a reference for aligning the tops of all circles.
# - **Key Points**:
#   - `[x, y, z]`: Specifies the coordinates of the point in 3D space.
#   - `[0, 2.5, 0]`: Places the reference point directly above the origin, at `y = 2.5`.
#
# ---
#
# #### **5. `*[circle.animate.align_to(point, UP) for circle in circles]`**
# - **Purpose**: Aligns the top edges of all circles with a horizontal line passing through the reference point.
# - **Method**:
#   - `.align_to(point, direction)`: Aligns the object's edge (in this case, `UP`) to the corresponding direction relative to the reference point (`point`).
#
# ---
#
# ### Summary
# This script demonstrates:
# 1. **Dynamic Object Creation**:
#    - Creation of circles with varying radii using list comprehensions and dynamic formulas.
# 2. **Alignment Methods**:
#    - `.align_to(mobject, direction)`: Aligning objects with other objects.
#    - `.align_to(point, direction)`: Aligning objects with a reference point in 3D space.
# 3. **Layered Animation**:
#    - Combining animations to position and align objects progressively.
# 4. **Use of Reference Points**:
#    - Employing specific 3D points for precise alignment.
#
# This example showcases how to combine object positioning and alignment techniques for structured and visually organized scenes.

# %%
# %%manim -v WARNING -qh --disable_caching TextAndMath
#
# class TextAndMath(Scene):
#     def construct(self):
#         text = Tex("Hello Manim!").shift(LEFT * 2)
#
#         # note that we're using Python's r-strings for cleaner code
#         formula = MathTex(r"\sum_{i = 0}^\infty \frac{1}{2^i} = 2").shift(RIGHT * 2)
#
#         self.play(Write(formula), Write(text), run_time = 2)
#         self.wait()
#         self.play(FadeOut(formula), FadeOut(text))
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `TextAndMath(Scene)`**
# This class creates a scene where text and a mathematical formula are displayed and then faded out.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `text = Tex("Hello Manim!").shift(LEFT * 2)`**
# - **Purpose**: Creates a text object and shifts it to the left.
# - **Key Points**:
#   - `Tex("Hello Manim!")`: Renders the text "Hello Manim!" using LaTeX-like formatting.
#   - `.shift(LEFT * 2)`: Moves the text 2 units to the left.
#
# #### **2. `formula = MathTex(r"\sum_{i = 0}^\infty \frac{1}{2^i} = 2").shift(RIGHT * 2)`**
# - **Purpose**: Creates a mathematical formula object and shifts it to the right.
# - **Key Points**:
#   - `MathTex(r"...")`: Renders a mathematical formula using LaTeX syntax. The `r` before the string indicates a raw string to avoid escaping special characters in LaTeX.
#   - The formula represents an infinite series: \( \sum_{i=0}^\infty \frac{1}{2^i} = 2 \).
#   - `.shift(RIGHT * 2)`: Moves the formula 2 units to the right.
#
# #### **3. `self.play(Write(formula), Write(text), run_time=2)`**
# - **Purpose**: Animates the writing of the text and the formula on the screen over 2 seconds.
# - **Key Points**:
#   - `Write()`: Animates the stroke-by-stroke drawing of text or math objects.
#   - `run_time=2`: Specifies that the animation should last 2 seconds.
#
# #### **4. `self.wait()`**
# - **Purpose**: Pauses the animation for the default amount of time (1 second) to allow the viewer to absorb the scene.
# - **Method**:
#   - `self.wait()`: Introduces a pause in the animation timeline.
#
# #### **5. `self.play(FadeOut(formula), FadeOut(text))`**
# - **Purpose**: Fades out both the formula and the text simultaneously.
# - **Key Points**:
#   - `FadeOut()`: Smoothly removes objects from the scene by reducing their opacity to zero.
#
# ---
#
# ### Summary
# This script demonstrates:
# 1. **Text and Math Rendering**:
#    - Using `Tex` for plain text with LaTeX-like formatting.
#    - Using `MathTex` for mathematical expressions in LaTeX.
# 2. **Positioning**:
#    - Applying `.shift()` to move objects to specific positions.
# 3. **Animations**:
#    - Sequential animations like `Write()` for drawing and `FadeOut()` for removal.
# 4. **Pausing**:
#    - Using `self.wait()` to add breaks for better scene pacing.
#
# This example combines textual and mathematical elements, making it useful for illustrating concepts that mix written explanations with formulas.

# %%
# %%manim -v WARNING --progress_bar None -qh --disable_caching ShuffleExample
#
# class ShuffleExample(Scene):
#     def construct(self):
#         # Define positions for the circles
#         positions = [
#             UP * 1.5 + LEFT * 2,
#             UP * 1.5 + RIGHT * 2,
#             DOWN * 1.5 + LEFT * 2,
#             DOWN * 1.5 + RIGHT * 2,
#         ]
#
#         # Create circles and place them at the specified positions
#         circles = [Circle(color=WHITE).shift(pos) for pos in positions]
#
#         # Write circles to the scene
#         self.play(*[Write(circle) for circle in circles])
#
#         # Swap circles
#         self.play(Swap(circles[0], circles[2]))
#         self.play(Swap(circles[2], circles[1]), path_arc = 0)
#         self.play(Swap(circles[2], circles[3], path_arc=160 * DEGREES))
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `ShuffleExample(Scene)`**
# This class creates a scene where circles are positioned in specific locations and then swapped.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `positions = [...]`**
# - **Purpose**: Defines the positions for the circles using vector arithmetic.
# - **Key Points**:
#   - Each position is a combination of `UP`, `DOWN`, `LEFT`, and `RIGHT` vectors.
#   - Examples:
#     - `UP * 1.5 + LEFT * 2`: Places a circle 1.5 units up and 2 units to the left.
#     - `DOWN * 1.5 + RIGHT * 2`: Places a circle 1.5 units down and 2 units to the right.
#
# #### **2. `circles = [Circle(color=WHITE).shift(pos) for pos in positions]`**
# - **Purpose**: Creates a list of white circles and shifts each one to its corresponding position.
# - **Key Points**:
#   - `Circle(color=WHITE)`: Instantiates a white circle.
#   - `.shift(pos)`: Moves each circle to the position defined in the `positions` list.
#
# #### **3. `self.play(*[Write(circle) for circle in circles])`**
# - **Purpose**: Animates the creation of all circles.
# - **Key Points**:
#   - `[Write(circle) for circle in circles]`: Generates `Write` animations for all circles.
#   - `*`: Unpacks the list of animations into separate arguments for `self.play`.
#
# #### **4. `self.play(Swap(circles[0], circles[2]))`**
# - **Purpose**: Swaps the positions of the first and third circles.
# - **Method**:
#   - `Swap(mobject1, mobject2)`: Animates the two specified objects swapping their positions.
#   - The animation creates a smooth, curved path for the swap.
#
# #### **5. `self.play(Swap(circles[1], circles[3], path_arc=160 * DEGREES))`**
# - **Purpose**: Swaps the second and fourth circles with a defined path curvature.
# - **Key Points**:
#   - `path_arc=160 * DEGREES`: Specifies the curvature of the path during the swap, creating a visually distinct arc.
#
# ---
#
# ### Summary
# This script demonstrates:
# 1. **Dynamic Object Positioning**:
#    - Using vector arithmetic to define positions.
# 2. **List Comprehensions**:
#    - Efficiently creating and positioning multiple objects.
# 3. **Swapping Objects**:
#    - The `Swap()` animation for smoothly interchanging positions of two objects.
#    - The `path_arc` parameter to add curvature to the swap animation.
# 4. **Sequential Animations**:
#    - Animations are applied step by step, allowing for clear visualization of each action.
#
# This example is useful for illustrating transformations or reordering concepts in a visually appealing manner.

# %%
# %%manim -v WARNING  --progress_bar None  -qh --disable_caching StretchToFitHeightExample
#
# class StretchToFitHeightExample(Scene):
#     def construct(self):
#         # Define positions for the squares
#         positions = [
#             LEFT * 2.5,
#             RIGHT * 2.5
#         ]
#
#         # Create squares and position them
#         squares = [Square().shift(pos) for pos in positions]
#
#         # Write the squares to the scene
#         self.play(*[Write(square) for square in squares])
#
#         # Apply different height adjustments
#         self.play(
#             squares[0].animate.stretch_to_fit_height(3.5),
#             squares[1].animate.set_height(3.5),
#         )
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Code Analysis: Main Functions and Methods
#
# ### **Class: `StretchToFitHeightExample(Scene)`**
# This class creates a scene where two squares are resized to the same height using different methods.
#
# ---
#
# ### **Unique Elements in `construct(self)`**
#
# #### **1. `positions = [...]`**
# - **Purpose**: Defines the positions for the two squares.
# - **Key Points**:
#   - `LEFT * 2.5`: Places the first square 2.5 units to the left of the origin.
#   - `RIGHT * 2.5`: Places the second square 2.5 units to the right of the origin.
#
# #### **2. `squares = [Square().shift(pos) for pos in positions]`**
# - **Purpose**: Creates a list of squares and shifts each one to its respective position.
# - **Key Points**:
#   - `Square()`: Creates a square with default dimensions.
#   - `.shift(pos)`: Moves the square to the specified position.
#
# #### **3. `self.play(*[Write(square) for square in squares])`**
# - **Purpose**: Animates the creation of both squares using the `Write` animation.
# - **Key Points**:
#   - `*[Write(square) for square in squares]`: Generates and unpacks the `Write` animations for the squares.
#
# #### **4. `squares[0].animate.stretch_to_fit_height(3.5)`**
# - **Purpose**: Adjusts the height of the first square to 3.5 units while preserving its width.
# - **Method**:
#   - `.stretch_to_fit_height(height)`: Changes the height of the object to the specified value, but does **not maintain aspect ratio**. The width remains unchanged, leading to a "stretched" appearance.
#
# #### **5. `squares[1].animate.set_height(3.5)`**
# - **Purpose**: Adjusts the height of the second square to 3.5 units while maintaining its aspect ratio.
# - **Method**:
#   - `.set_height(height)`: Resizes the object to the specified height **while maintaining its original aspect ratio**. This means the width is scaled proportionally.
#
# ---
#
# ### **Comparison of Methods**
# | Method                     | Aspect Ratio Maintained | Resulting Shape       |
# |----------------------------|-------------------------|-----------------------|
# | `.stretch_to_fit_height()` | No                      | Height changes only, width remains constant. |
# | `.set_height()`            | Yes                     | Height changes, width scales proportionally. |
#
# ---
#
# ### **Summary**
# This script demonstrates:
# 1. **Object Positioning**:
#    - Use of vector arithmetic to place objects in different positions.
# 2. **Height Adjustment**:
#    - `.stretch_to_fit_height()` for resizing height without maintaining aspect ratio.
#    - `.set_height()` for resizing height with aspect ratio preservation.
# 3. **Comparative Animation**:
#    - Shows how the two methods yield visually different results, making it a good example for explaining resizing behavior.
#
# This example highlights the flexibility of Manim's transformation methods and their impact on object proportions.

# %%
# %%manim -v WARNING  --progress_bar None  -qh --disable_caching ArrowExample
#
# class ArrowExample(Scene):
#     def construct(self):
#         a1 = Arrow(start=UP, end=DOWN).shift(LEFT * 2)
#         a2 = Arrow(start=DOWN, end=UP).shift(RIGHT * 2)
#
#         self.play(Write(a1), Write(a2))
# Out:
# Manim Community v0.18.1
# <video controls autoplay loop style="max-width: 50%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### Reference
# * https://docs.manim.community/en/stable/index.html
# * https://slama.dev/manim/introduction/
# *
